# %%
#Check if numba can detect the GPU
# !numba -s
# Out:
# System info:
# --------------------------------------------------------------------------------
# __Time Stamp__
# Report started (local time)                   : 2025-02-28 13:27:42.408331
# UTC start time                                : 2025-02-28 20:27:42.408346
# Running time (s)                              : 15.112425
#
# __Hardware Information__
# Machine                                       : x86_64
# CPU Name                                      : znver3
# CPU Count                                     : 128
# Number of accessible CPUs                     : 1
# List of accessible CPUs cores                 : 0
# CFS Restrictions (CPUs worth of runtime)      : None
#
# CPU Features                                  : 64bit adx aes avx avx2 avx512bf16
#                                                 avx512bitalg avx512bw avx512cd
#                                                 avx512dq avx512f avx512ifma
#                                                 avx512vbmi avx512vbmi2 avx512vl
#                                                 avx512vnni avx512vpopcntdq bmi
#                                                 bmi2 clflushopt clwb clzero cmov
#                                                 crc32 cx16 cx8 f16c fma fsgsbase
#                                                 fxsr gfni invpcid lzcnt mmx movbe
#                                                 mwaitx pclmul pku popcnt prfchw
#                                                 rdpid rdpru rdrnd rdseed sahf sha
#                                                 shstk sse sse2 sse3 sse4.1 sse4.2
#                                                 sse4a ssse3 vaes vpclmulqdq
#                                                 wbnoinvd xsave xsavec xsaveopt
#                                                 xsaves
#
# Memory Total (MB)                             : 386234
# Memory Available (MB)                         : 363286
#
# __OS Information__
# Platform Name                                 : Linux-4.18.0-477.10.1.el8_8.x86_64-x86_64-with-glibc2.28
# Platform Release                              : 4.18.0-477.10.1.el8_8.x86_64
# OS Name                                       : Linux
# OS Version                                    : #1 SMP Wed Apr 5 13:35:01 EDT 2023
# OS Specific Version                           : ?
# Libc Version                                  : glibc 2.28
#
# __Python Information__
# Python Compiler                               : GCC 13.3.0
# Python Implementation                         : CPython
# Python Version                                : 3.12.8
# Python Locale                                 : en_US.UTF-8
#
# __Numba Toolchain Versions__
# Numba Version                                 : 0.61.0
# llvmlite Version                              : 0.44.0
#
# __LLVM Information__
# LLVM Version                                  : 15.0.7
#
# __CUDA Information__
# CUDA Target Implementation                    : Built-in
# CUDA Device Initialized                       : True
# CUDA Driver Version                           : 12.4
# CUDA Runtime Version                          : 12.4
# CUDA NVIDIA Bindings Available                : False
# CUDA NVIDIA Bindings In Use                   : False
# CUDA Minor Version Compatibility Available    : False
# CUDA Minor Version Compatibility Needed       : False
# CUDA Minor Version Compatibility In Use       : False
# CUDA Detect Output:
# Found 2 CUDA devices
# id 0    b'NVIDIA H100 80GB HBM3'                              [SUPPORTED]
#                       Compute Capability: 9.0
#                            PCI Device ID: 0
#                               PCI Bus ID: 4
#                                     UUID: GPU-64fbd2d0-4eab-1c5d-a52d-a6fea3f918f3
#                                 Watchdog: Disabled
#              FP32/FP64 Performance Ratio: 2
# id 1    b'NVIDIA H100 80GB HBM3'                              [SUPPORTED]
#                       Compute Capability: 9.0
#                            PCI Device ID: 0
#                               PCI Bus ID: 100
#                                     UUID: GPU-fe35696d-2fbf-9914-c27b-400e2da3ccbc
#                                 Watchdog: Disabled
#              FP32/FP64 Performance Ratio: 2
# Summary:
# 	2/2 devices are supported
#
# CUDA Libraries Test Output:
# Finding driver from candidates:
# 	libcuda.so
# 	libcuda.so.1
# 	/usr/lib/libcuda.so
# 	/usr/lib/libcuda.so.1
# 	/usr/lib64/libcuda.so
# 	/usr/lib64/libcuda.so.1
# Using loader <class 'ctypes.CDLL'>
# 	Trying to load driver...	ok
# 		Loaded from libcuda.so
# 	Mapped libcuda.so paths:
# 		/usr/lib64/libcuda.so.550.54.15
# Finding nvvm from Conda environment (NVIDIA package)
# 	Located at /kfs2/projects/hpcapps/nsawant/myEnv/nvvm/lib64/libnvvm.so.4.0.0
# 	Trying to open library...	ok
# Finding nvrtc from Conda environment (NVIDIA package)
# 	Located at /kfs2/projects/hpcapps/nsawant/myEnv/lib/libnvrtc.so.12.4.127
# 	Trying to open library...	ok
# Finding cudart from Conda environment (NVIDIA package)
# 	Located at /kfs2/projects/hpcapps/nsawant/myEnv/lib/libcudart.so.12.4.127
# 	Trying to open library...	ok
# Finding cudadevrt from Conda environment (NVIDIA package)
# 	Located at /kfs2/projects/hpcapps/nsawant/myEnv/lib/libcudadevrt.a
# 	Checking library...	ok
# Finding libdevice from Conda environment (NVIDIA package)
# 	Located at /kfs2/projects/hpcapps/nsawant/myEnv/nvvm/libdevice/libdevice.10.bc
# 	Checking library...	ok
#
#
# __NumPy Information__
# NumPy Version                                 : 2.1.3
# NumPy Supported SIMD features                 : ('MMX', 'SSE', 'SSE2', 'SSE3', 'SSSE3', 'SSE41', 'POPCNT', 'SSE42', 'AVX', 'F16C', 'FMA3', 'AVX2', 'AVX512F', 'AVX512CD', 'AVX512VPOPCNTDQ', 'AVX512VL', 'AVX512BW', 'AVX512DQ', 'AVX512VNNI', 'AVX512IFMA', 'AVX512VBMI', 'AVX512VBMI2', 'AVX512BITALG', 'AVX512_SKX', 'AVX512_CLX', 'AVX512_CNL', 'AVX512_ICL')
# NumPy Supported SIMD dispatch                 : ('SSSE3', 'SSE41', 'POPCNT', 'SSE42', 'AVX', 'F16C', 'FMA3', 'AVX2', 'AVX512F', 'AVX512CD', 'AVX512_KNL', 'AVX512_KNM', 'AVX512_SKX', 'AVX512_CLX', 'AVX512_CNL', 'AVX512_ICL')
# NumPy Supported SIMD baseline                 : ('SSE', 'SSE2', 'SSE3')
# NumPy AVX512_SKX support detected             : True
#
# __SVML Information__
# SVML State, config.USING_SVML                 : False
# SVML Library Loaded                           : False
# llvmlite Using SVML Patched LLVM              : True
# SVML Operational                              : False
#
# __Threading Layer Information__
# TBB Threading Layer Available                 : True
# +-->TBB imported successfully.
# OpenMP Threading Layer Available              : True
# +-->Vendor: GNU
# Workqueue Threading Layer Available           : True
# +-->Workqueue imported successfully.
#
# __Numba Environment Variable Information__
# None found.
#
# __Conda Information__
# Conda Build                                   : 24.5.1
# Conda Env                                     : 24.5.0
# Conda Platform                                : linux-64
# Conda Python Version                          : 3.12.4.final.0
# Conda Root Writable                           : False
#
# __Installed Packages__
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# adwaita-icon-theme        47.0                     unix_0    conda-forge
# alsa-lib                  1.2.13               hb9d3cd8_0    conda-forge
# anyio                     4.6.2           py312h06a4308_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0          py312h5eee18b_1
# asttokens                 2.0.5              pyhd3eb1b0_0
# async-lru                 2.0.4           py312h06a4308_0
# at-spi2-atk               2.38.0               h0630a04_3    conda-forge
# at-spi2-core              2.40.3               h0630a04_0    conda-forge
# atk-1.0                   2.38.0               h04ea711_2    conda-forge
# attr                      2.5.1                h166bdaf_1    conda-forge
# attrs                     24.3.0          py312h06a4308_0
# aws-c-auth                0.8.1                h205f482_0    conda-forge
# aws-c-cal                 0.8.1                h1a47875_3    conda-forge
# aws-c-common              0.10.6               hb9d3cd8_0    conda-forge
# aws-c-compression         0.3.0                h4e1184b_5    conda-forge
# aws-c-event-stream        0.5.0               h7959bf6_11    conda-forge
# aws-c-http                0.9.2                hefd7a92_4    conda-forge
# aws-c-io                  0.15.3               h173a860_6    conda-forge
# aws-c-mqtt                0.11.0              h11f4f37_12    conda-forge
# aws-c-s3                  0.7.9                he1b24dc_1    conda-forge
# aws-c-sdkutils            0.2.2                h4e1184b_0    conda-forge
# aws-checksums             0.2.2                h4e1184b_4    conda-forge
# aws-crt-cpp               0.29.9               he0e7f3f_2    conda-forge
# aws-sdk-cpp               1.11.489             h4d475cb_0    conda-forge
# azure-core-cpp            1.14.0               h5cfcd09_0    conda-forge
# azure-identity-cpp        1.10.0               h113e628_0    conda-forge
# azure-storage-blobs-cpp   12.13.0              h3cf044e_1    conda-forge
# azure-storage-common-cpp  12.8.0               h736e048_1    conda-forge
# azure-storage-files-datalake-cpp 12.12.0              ha633028_1    conda-forge
# babel                     2.16.0          py312h06a4308_0
# beautifulsoup4            4.12.3          py312h06a4308_0
# binutils_impl_linux-64    2.43                 h4bf12b8_2    conda-forge
# binutils_linux-64         2.43                 h4852527_2    conda-forge
# blas                      2.128                  openblas    conda-forge
# blas-devel                3.9.0           28_h1ea3ea9_openblas    conda-forge
# bleach                    6.2.0           py312h06a4308_0
# bokeh                     3.6.2           py312h06a4308_0
# bottleneck                1.4.2           py312ha883a20_0
# brotli-python             1.0.9           py312h6a678d5_9
# bzip2                     1.0.8                h4bc722e_7    conda-forge
# c-ares                    1.34.4               hb9d3cd8_0    conda-forge
# ca-certificates           2025.1.31            hbcca054_0    conda-forge
# cairo                     1.18.2               h3394656_1    conda-forge
# certifi                   2025.1.31          pyhd8ed1ab_0    conda-forge
# cffi                      1.17.1          py312h1fdaa30_1
# charset-normalizer        3.3.2              pyhd3eb1b0_0
# click                     8.1.7           py312h06a4308_0
# cloudpickle               3.0.0           py312h06a4308_0
# comm                      0.2.1           py312h06a4308_0
# contourpy                 1.3.1           py312hdb19cb5_0
# cuda-cccl_linux-64        12.4.127             h06a4308_2
# cuda-crt-dev_linux-64     12.4.131             ha770c72_1    conda-forge
# cuda-crt-tools            12.4.131             ha770c72_1    conda-forge
# cuda-cudart               12.4.127             h99ab3db_0
# cuda-cudart-dev           12.4.127             h99ab3db_0
# cuda-cudart-dev_linux-64  12.4.127             hd681fbe_0
# cuda-cudart-static        12.4.127             h99ab3db_0
# cuda-cudart-static_linux-64 12.4.127             hd681fbe_0
# cuda-cudart_linux-64      12.4.127             hd681fbe_0
# cuda-cupti                12.4.127             h6a678d5_1
# cuda-driver-dev_linux-64  12.4.127             h85509e4_2    conda-forge
# cuda-libraries            12.4.1               h06a4308_1
# cuda-nvcc                 12.4.131             hcdd1206_1    conda-forge
# cuda-nvcc-dev_linux-64    12.4.131             ha770c72_1    conda-forge
# cuda-nvcc-impl            12.4.131             hd3aeb46_1    conda-forge
# cuda-nvcc-tools           12.4.131             hd3aeb46_1    conda-forge
# cuda-nvcc_linux-64        12.4.131             h8a487aa_1    conda-forge
# cuda-nvrtc                12.4.127             he02047a_2    conda-forge
# cuda-nvtx                 12.4.127             h6a678d5_1
# cuda-nvvm-dev_linux-64    12.4.131             ha770c72_1    conda-forge
# cuda-nvvm-impl            12.4.131             h59595ed_1    conda-forge
# cuda-nvvm-tools           12.4.131             h59595ed_1    conda-forge
# cuda-opencl               12.4.127             h6a678d5_0
# cuda-runtime              12.4.1               hb982923_0
# cuda-version              12.4                 h3060b56_3    conda-forge
# cudnn                     9.3.0.75             h62a6f1c_2    conda-forge
# cupy                      13.3.0          py312h7d319b9_2    conda-forge
# cupy-core                 13.3.0          py312h1acd1a8_2    conda-forge
# cutensor                  2.1.0.9              h2b4c902_0    conda-forge
# cycler                    0.11.0             pyhd3eb1b0_0
# cyrus-sasl                2.1.27               h54b06d7_7    conda-forge
# cytoolz                   1.0.1           py312h5eee18b_0
# dask                      2024.12.1       py312h06a4308_0
# dask-core                 2024.12.1       py312h06a4308_0
# dask-expr                 1.1.21          py312h06a4308_0
# dask-jobqueue             0.9.0           py312h06a4308_0
# dbus                      1.13.18              hb2f20db_0
# debugpy                   1.8.11          py312h6a678d5_0
# decorator                 5.1.1              pyhd3eb1b0_0
# defusedxml                0.7.1              pyhd3eb1b0_0
# distributed               2024.12.1       py312h06a4308_0
# entrypoints               0.4             py312h06a4308_0
# epoxy                     1.5.10               h166bdaf_1    conda-forge
# executing                 0.8.3              pyhd3eb1b0_0
# expat                     2.6.4                h6a678d5_0
# fastrlock                 0.8.3           py312h6edf5ed_1    conda-forge
# filelock                  3.17.0                   pypi_0    pypi
# font-ttf-dejavu-sans-mono 2.37                 hd3eb1b0_0
# font-ttf-inconsolata      2.001                hcb22688_0
# font-ttf-source-code-pro  2.030                hd3eb1b0_0
# font-ttf-ubuntu           0.83                 h8b1ccd4_0
# fontconfig                2.15.0               h7e30c49_1    conda-forge
# fonts-anaconda            1                    h8fa9717_0
# fonts-conda-ecosystem     1                    hd3eb1b0_0
# fonttools                 4.55.3          py312h5eee18b_0
# freetype                  2.12.1               h267a509_2    conda-forge
# fribidi                   1.0.10               h7b6447c_0
# fsspec                    2024.12.0       py312h06a4308_0
# gcc_impl_linux-64         12.4.0               h26ba24d_2    conda-forge
# gcc_linux-64              12.4.0               h6b7512a_8    conda-forge
# gdk-pixbuf                2.42.12              hb9ae30d_0    conda-forge
# gettext                   0.22.5               he02047a_3    conda-forge
# gettext-tools             0.22.5               he02047a_3    conda-forge
# gflags                    2.2.2                h6a678d5_1
# glib                      2.82.2               h07242d1_1    conda-forge
# glib-tools                2.82.2               h4833e2c_1    conda-forge
# glog                      0.7.1                hbabe93e_0    conda-forge
# graphite2                 1.3.14               h295c915_1
# graphviz                  12.2.1               h5ae0cbf_1    conda-forge
# gst-plugins-base          1.24.7               h0a52356_0    conda-forge
# gstreamer                 1.24.7               hf3bb09a_0    conda-forge
# gtk3                      3.24.43              h021d004_3    conda-forge
# gts                       0.7.6                hb67d8dd_3
# gxx_impl_linux-64         12.4.0               h3ff227c_2    conda-forge
# gxx_linux-64              12.4.0               h8489865_8    conda-forge
# h11                       0.14.0          py312h06a4308_0
# harfbuzz                  10.2.0               h4bba637_0    conda-forge
# heapdict                  1.0.1              pyhd3eb1b0_0
# hicolor-icon-theme        0.17                 h06a4308_2
# httpcore                  1.0.2           py312h06a4308_0
# httpx                     0.27.0          py312h06a4308_0
# icu                       75.1                 he02047a_0    conda-forge
# idna                      3.7             py312h06a4308_0
# importlib-metadata        8.6.1              pyha770c72_0    conda-forge
# ipycytoscape              1.3.3              pyhd8ed1ab_1    conda-forge
# ipykernel                 6.29.5          py312h06a4308_1
# ipympl                    0.9.6              pyhd8ed1ab_0    conda-forge
# ipyparallel               8.6.1           py312h06a4308_0
# ipython                   8.30.0          py312h06a4308_0
# ipython_genutils          0.2.0              pyhd8ed1ab_2    conda-forge
# ipywidgets                8.1.5           py312h06a4308_0
# jedi                      0.19.2          py312h06a4308_0
# jinja2                    3.1.5           py312h06a4308_0
# json5                     0.9.25          py312h06a4308_0
# jsonschema                4.23.0          py312h06a4308_0
# jsonschema-specifications 2023.7.1        py312h06a4308_0
# jupyter-lsp               2.2.0           py312h06a4308_0
# jupyter_client            8.6.3           py312h06a4308_0
# jupyter_core              5.7.2           py312h06a4308_0
# jupyter_events            0.10.0          py312h06a4308_0
# jupyter_server            2.14.1          py312h06a4308_0
# jupyter_server_terminals  0.4.4           py312h06a4308_1
# jupyterlab                4.3.5              pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         2.27.3          py312h06a4308_0
# jupyterlab_widgets        3.0.13          py312h06a4308_0
# kernel-headers_linux-64   3.10.0              he073ed8_18    conda-forge
# kiwisolver                1.4.8           py312h6a678d5_0
# krb5                      1.21.3               h143b758_0
# lame                      3.100                h7b6447c_0
# lcms2                     2.16                 hb7c19ff_0    conda-forge
# ld_impl_linux-64          2.43                 h712a8e2_2    conda-forge
# lerc                      4.0.0                h6a678d5_0
# libabseil                 20240722.0      cxx17_hbbce691_4    conda-forge
# libarrow                  19.0.0           h00a82cf_8_cpu    conda-forge
# libarrow-acero            19.0.0           hcb10f89_8_cpu    conda-forge
# libarrow-dataset          19.0.0           hcb10f89_8_cpu    conda-forge
# libarrow-substrait        19.0.0           h08228c5_8_cpu    conda-forge
# libasprintf               0.22.5               he8f35ee_3    conda-forge
# libasprintf-devel         0.22.5               he8f35ee_3    conda-forge
# libblas                   3.9.0           28_h59b9bed_openblas    conda-forge
# libbrotlicommon           1.1.0                hb9d3cd8_2    conda-forge
# libbrotlidec              1.1.0                hb9d3cd8_2    conda-forge
# libbrotlienc              1.1.0                hb9d3cd8_2    conda-forge
# libcap                    2.71                 h39aace5_0    conda-forge
# libcblas                  3.9.0           28_he106b2a_openblas    conda-forge
# libclang-cpp19.1          19.1.7          default_hb5137d0_1    conda-forge
# libclang13                19.1.7          default_h9c6a7e4_1    conda-forge
# libcrc32c                 1.1.2                h6a678d5_0
# libcublas                 12.4.5.8             h99ab3db_1
# libcufft                  11.2.1.3             h99ab3db_1
# libcufile                 1.9.1.3              h99ab3db_1
# libcups                   2.3.3                h4637d8d_4    conda-forge
# libcurand                 10.3.5.147           h99ab3db_1
# libcurl                   8.11.1               h332b0f4_0    conda-forge
# libcusolver               11.6.1.9             h99ab3db_1
# libcusparse               12.3.1.170           h99ab3db_1
# libdeflate                1.23                 h4ddbbb0_0    conda-forge
# libdrm                    2.4.124              hb9d3cd8_0    conda-forge
# libedit                   3.1.20230828         h5eee18b_0
# libegl                    1.7.0                ha4b6fd6_2    conda-forge
# libev                     4.33                 h7f8727e_1
# libevent                  2.1.12               hf998b51_1    conda-forge
# libexpat                  2.6.4                h5888daf_0    conda-forge
# libfabric                 2.0.0                ha770c72_1    conda-forge
# libfabric1                2.0.0                h14e6f36_1    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libflac                   1.4.3                h59595ed_0    conda-forge
# libgcc                    14.2.0               h767d61c_2    conda-forge
# libgcc-devel_linux-64     12.4.0             h1762d19_102    conda-forge
# libgcc-ng                 14.2.0               h69a702a_2    conda-forge
# libgcrypt-lib             1.11.0               hb9d3cd8_2    conda-forge
# libgd                     2.3.3               h6f5c62b_11    conda-forge
# libgettextpo              0.22.5               he02047a_3    conda-forge
# libgettextpo-devel        0.22.5               he02047a_3    conda-forge
# libgfortran               14.2.0               h69a702a_1    conda-forge
# libgfortran-ng            14.2.0               h69a702a_1    conda-forge
# libgfortran5              14.2.0               hd5240d6_1    conda-forge
# libgl                     1.7.0                ha4b6fd6_2    conda-forge
# libglib                   2.82.2               h2ff4ddf_1    conda-forge
# libglvnd                  1.7.0                ha4b6fd6_2    conda-forge
# libglx                    1.7.0                ha4b6fd6_2    conda-forge
# libgomp                   14.2.0               h767d61c_2    conda-forge
# libgoogle-cloud           2.34.0               h2b5623c_0    conda-forge
# libgoogle-cloud-storage   2.34.0               h0121fbd_0    conda-forge
# libgpg-error              1.51                 hbd13f7d_1    conda-forge
# libgrpc                   1.67.1               h25350d4_1    conda-forge
# libhwloc                  2.11.2          default_h0d58e46_1001    conda-forge
# libiconv                  1.17                 hd590300_2    conda-forge
# libjpeg-turbo             3.0.3                h5eee18b_0
# liblapack                 3.9.0           28_h7ac8fdf_openblas    conda-forge
# liblapacke                3.9.0           28_he2f377e_openblas    conda-forge
# libllvm15                 15.0.7               ha7bfdaf_5    conda-forge
# libllvm19                 19.1.7               ha7bfdaf_1    conda-forge
# liblzma                   5.6.4                hb9d3cd8_0    conda-forge
# libnghttp2                1.64.0               h161d5f1_0    conda-forge
# libnl                     3.11.0               hb9d3cd8_0    conda-forge
# libnpp                    12.2.5.30            h99ab3db_1
# libnsl                    2.0.1                hd590300_0    conda-forge
# libntlm                   1.6                  h7f8727e_0
# libnvfatbin               12.4.127             h7934f7d_2
# libnvjitlink              12.4.127             h99ab3db_1
# libnvjpeg                 12.3.1.117           h6a678d5_1
# libogg                    1.3.5                h27cfd23_1
# libopenblas               0.3.28          pthreads_h94d23a6_1    conda-forge
# libopentelemetry-cpp      1.18.0               hfcad708_1    conda-forge
# libopentelemetry-cpp-headers 1.18.0               ha770c72_1    conda-forge
# libopus                   1.3.1                h5eee18b_1
# libparquet                19.0.0           h081d1f1_8_cpu    conda-forge
# libpciaccess              0.18                 hd590300_0    conda-forge
# libpmix                   5.0.6                h658e747_0    conda-forge
# libpng                    1.6.46               h943b412_0    conda-forge
# libpq                     17.2                 h3b95a9b_1    conda-forge
# libprotobuf               5.28.3               h6128344_1    conda-forge
# libre2-11                 2024.07.02           hbbce691_2    conda-forge
# librsvg                   2.58.4               h49af25d_2    conda-forge
# libsanitizer              12.4.0               ha732cd4_2    conda-forge
# libsndfile                1.2.2                hc60ed4a_1    conda-forge
# libsodium                 1.0.18               h7b6447c_0
# libsqlite                 3.48.0               hee588c1_1    conda-forge
# libssh2                   1.11.1               hf672d98_0    conda-forge
# libstdcxx                 14.2.0               h8f9b012_2    conda-forge
# libstdcxx-devel_linux-64  12.4.0             h1762d19_102    conda-forge
# libstdcxx-ng              14.2.0               h4852527_2    conda-forge
# libsystemd0               257.2                h3dc2cb9_0    conda-forge
# libthrift                 0.21.0               h0e7cc3e_0    conda-forge
# libtiff                   4.7.0                hd9ff511_3    conda-forge
# libudev1                  257.2                h9a4d06a_0    conda-forge
# libutf8proc               2.10.0               h4c51ac1_0    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libuv                     1.50.0               hb9d3cd8_0    conda-forge
# libvorbis                 1.3.7                h7b6447c_0
# libwebp-base              1.5.0                h851e524_0    conda-forge
# libxcb                    1.17.0               h8a09558_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libxkbcommon              1.8.0                hc4a0caf_0    conda-forge
# libxml2                   2.13.5               h8d12d68_1    conda-forge
# libzlib                   1.3.1                hb9d3cd8_2    conda-forge
# llvmlite                  0.44.0          py312h6a678d5_0
# locket                    1.0.0           py312h06a4308_0
# lz4                       4.3.3           py312hf0f0c11_2    conda-forge
# lz4-c                     1.10.0               h5888daf_1    conda-forge
# markupsafe                3.0.2           py312h5eee18b_0
# matplotlib                3.10.0          py312h06a4308_0
# matplotlib-base           3.10.0          py312hbfdbfaf_0
# matplotlib-inline         0.1.6           py312h06a4308_0
# mistune                   2.0.4           py312h06a4308_0
# mpg123                    1.32.9               hc50e24c_0    conda-forge
# mpi                       1.0                     openmpi    conda-forge
# mpi4py                    4.0.2           py312h5ca6011_0    conda-forge
# mpmath                    1.3.0                    pypi_0    pypi
# msgpack-python            1.0.3           py312hdb19cb5_0
# mysql-common              9.0.1                h266115a_4    conda-forge
# mysql-libs                9.0.1                he0572af_4    conda-forge
# nbclient                  0.8.0           py312h06a4308_0
# nbconvert                 7.16.4          py312h06a4308_0
# nbformat                  5.10.4          py312h06a4308_0
# nccl                      2.25.1.1             ha44e49d_0    conda-forge
# ncurses                   6.5                  h2d0b736_3    conda-forge
# nest-asyncio              1.6.0           py312h06a4308_0
# networkx                  3.4.2                    pypi_0    pypi
# nlohmann_json             3.11.2               h6a678d5_0
# nodejs                    22.12.0              hf235a45_0    conda-forge
# notebook-shim             0.2.3           py312h06a4308_0
# nspr                      4.36                 h5888daf_0    conda-forge
# nss                       3.108                h159eef7_0    conda-forge
# numba                     0.61.0          py312h6a678d5_0
# numexpr                   2.10.1          py312hd28fd6d_0
# numpy                     2.1.3           py312h2809609_0
# numpy-base                2.1.3           py312he1a6c75_0
# nvidia-cublas-cu12        12.4.5.8                 pypi_0    pypi
# nvidia-cuda-cupti-cu12    12.4.127                 pypi_0    pypi
# nvidia-cuda-nvrtc-cu12    12.4.127                 pypi_0    pypi
# nvidia-cuda-runtime-cu12  12.4.127                 pypi_0    pypi
# nvidia-cudnn-cu12         9.1.0.70                 pypi_0    pypi
# nvidia-cufft-cu12         11.2.1.3                 pypi_0    pypi
# nvidia-curand-cu12        10.3.5.147               pypi_0    pypi
# nvidia-cusolver-cu12      11.6.1.9                 pypi_0    pypi
# nvidia-cusparse-cu12      12.3.1.170               pypi_0    pypi
# nvidia-cusparselt-cu12    0.6.2                    pypi_0    pypi
# nvidia-nccl-cu12          2.21.5                   pypi_0    pypi
# nvidia-nvjitlink-cu12     12.4.127                 pypi_0    pypi
# nvidia-nvtx-cu12          12.4.127                 pypi_0    pypi
# ocl-icd                   2.3.2                h5eee18b_1
# openblas                  0.3.28          pthreads_h6ec200e_1    conda-forge
# openjpeg                  2.5.3                h5fbd93e_0    conda-forge
# openldap                  2.6.9                he970967_0    conda-forge
# openmpi                   5.0.6              hb85ec53_102    conda-forge
# openssl                   3.4.1                h7b32b05_0    conda-forge
# orc                       2.0.3                h12ee42a_2    conda-forge
# overrides                 7.4.0           py312h06a4308_0
# packaging                 24.2            py312h06a4308_0
# pandas                    2.2.3           py312h6a678d5_0
# pandocfilters             1.5.0              pyhd3eb1b0_0
# pango                     1.56.1               h861ebed_0    conda-forge
# parso                     0.8.4           py312h06a4308_0
# partd                     1.4.2           py312h06a4308_0
# pcre2                     10.44                hba22ea6_2    conda-forge
# pexpect                   4.8.0              pyhd3eb1b0_3
# pillow                    11.1.0          py312h80c1187_0    conda-forge
# pip                       25.0               pyh8b19718_0    conda-forge
# pixman                    0.44.2               h29eaf8c_0    conda-forge
# platformdirs              3.10.0          py312h06a4308_0
# ply                       3.11            py312h06a4308_1
# prometheus-cpp            1.3.0                ha5d0236_0    conda-forge
# prometheus_client         0.21.0          py312h06a4308_0
# prompt-toolkit            3.0.43          py312h06a4308_0
# prompt_toolkit            3.0.43               hd3eb1b0_0
# psutil                    5.9.0           py312h5eee18b_1
# pthread-stubs             0.3                  h0ce48e5_1
# ptyprocess                0.7.0              pyhd3eb1b0_2
# pulseaudio-client         17.0                 hb77b528_0    conda-forge
# pure_eval                 0.2.2              pyhd3eb1b0_0
# pyarrow                   19.0.0          py312h7900ff3_0    conda-forge
# pyarrow-core              19.0.0          py312h01725c0_0_cpu    conda-forge
# pycparser                 2.21               pyhd3eb1b0_0
# pygments                  2.15.1          py312h06a4308_1
# pyparsing                 3.2.0           py312h06a4308_0
# pyqt                      5.15.10         py312h6a678d5_1
# pyqt5-sip                 12.13.0         py312h5eee18b_1
# pysocks                   1.7.1           py312h06a4308_0
# python                    3.12.8          h9e4cc4f_1_cpython    conda-forge
# python-dateutil           2.9.0post0      py312h06a4308_2
# python-fastjsonschema     2.20.0          py312h06a4308_0
# python-json-logger        3.2.1           py312h06a4308_0
# python-lmdb               1.6.2           py312h6a678d5_0
# python-tzdata             2023.3             pyhd3eb1b0_0
# python_abi                3.12                    5_cp312    conda-forge
# pytorch-cuda              12.4                 hc786d27_7    pytorch
# pytz                      2024.1          py312h06a4308_0
# pyyaml                    6.0.2           py312h5eee18b_0
# pyzmq                     26.2.0          py312h6a678d5_0
# qt-main                   5.15.15              hc3cb62f_2    conda-forge
# rdma-core                 55.0                 h5888daf_0    conda-forge
# re2                       2024.07.02           h9925aae_2    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# referencing               0.30.2          py312h06a4308_0
# requests                  2.32.3          py312h06a4308_1
# rfc3339-validator         0.1.4           py312h06a4308_0
# rfc3986-validator         0.1.1           py312h06a4308_0
# rpds-py                   0.22.3          py312h4aa5aa6_0
# s2n                       1.5.11               h072c03f_0    conda-forge
# scipy                     1.15.2                   pypi_0    pypi
# send2trash                1.8.2           py312h06a4308_1
# setuptools                72.1.0          py312h06a4308_0
# sip                       6.7.12          py312h6a678d5_1
# six                       1.16.0             pyhd3eb1b0_1
# snappy                    1.2.1                h6a678d5_0
# sniffio                   1.3.0           py312h06a4308_0
# sodshock                  0.1.9                    pypi_0    pypi
# sortedcontainers          2.4.0              pyhd3eb1b0_0
# soupsieve                 2.5             py312h06a4308_0
# spectate                  1.0.1              pyhd8ed1ab_0    conda-forge
# stack_data                0.2.0              pyhd3eb1b0_0
# sympy                     1.13.1                   pypi_0    pypi
# sysroot_linux-64          2.17                h0157908_18    conda-forge
# tbb                       2021.8.0             hdb19cb5_0
# tblib                     1.7.0              pyhd3eb1b0_0
# terminado                 0.17.1          py312h06a4308_0
# tinycss2                  1.4.0           py312h06a4308_0
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# tomli                     2.2.1              pyhd8ed1ab_1    conda-forge
# toolz                     1.0.0           py312h06a4308_0
# torchaudio                2.6.0                    pypi_0    pypi
# torchvision               0.21.0                   pypi_0    pypi
# tornado                   6.4.2           py312h5eee18b_0
# tqdm                      4.66.5          py312he106c6f_0
# traitlets                 5.14.3          py312h06a4308_0
# triton                    3.2.0                    pypi_0    pypi
# typing-extensions         4.12.2          py312h06a4308_0
# typing_extensions         4.12.2          py312h06a4308_0
# tzdata                    2025a                h78e105d_0    conda-forge
# ucc                       1.3.0                h2b97398_4    conda-forge
# ucx                       1.18.0               h8887438_1    conda-forge
# unicodedata2              15.1.0          py312h5eee18b_1
# urllib3                   2.3.0           py312h06a4308_0
# wayland                   1.23.1               h3e06ad9_0    conda-forge
# wcwidth                   0.2.5              pyhd3eb1b0_0
# webencodings              0.5.1           py312h06a4308_2
# websocket-client          1.8.0           py312h06a4308_0
# wheel                     0.45.1             pyhd8ed1ab_1    conda-forge
# widgetsnbextension        4.0.13          py312h06a4308_0
# xcb-util                  0.4.1                hb711507_2    conda-forge
# xcb-util-image            0.4.0                hb711507_2    conda-forge
# xcb-util-keysyms          0.4.1                hb711507_0    conda-forge
# xcb-util-renderutil       0.3.10               hb711507_0    conda-forge
# xcb-util-wm               0.4.2                hb711507_0    conda-forge
# xkeyboard-config          2.43                 hb9d3cd8_0    conda-forge
# xorg-libice               1.1.2                hb9d3cd8_0    conda-forge
# xorg-libsm                1.2.5                he73a12e_0    conda-forge
# xorg-libx11               1.8.11               h4f16b4b_0    conda-forge
# xorg-libxau               1.0.12               hb9d3cd8_0    conda-forge
# xorg-libxcomposite        0.4.6                hb9d3cd8_2    conda-forge
# xorg-libxcursor           1.2.3                hb9d3cd8_0    conda-forge
# xorg-libxdamage           1.1.6                hb9d3cd8_0    conda-forge
# xorg-libxdmcp             1.1.5                hb9d3cd8_0    conda-forge
# xorg-libxext              1.3.6                hb9d3cd8_0    conda-forge
# xorg-libxfixes            6.0.1                hb9d3cd8_0    conda-forge
# xorg-libxi                1.8.2                hb9d3cd8_0    conda-forge
# xorg-libxinerama          1.1.5                h5888daf_1    conda-forge
# xorg-libxrandr            1.5.4                hb9d3cd8_0    conda-forge
# xorg-libxrender           0.9.12               hb9d3cd8_0    conda-forge
# xorg-libxtst              1.2.5                hb9d3cd8_3    conda-forge
# xorg-libxxf86vm           1.1.6                hb9d3cd8_0    conda-forge
# xyzservices               2022.9.0        py312h06a4308_1
# yaml                      0.2.5                h7b6447c_0
# zeromq                    4.3.5                h6a678d5_0
# zict                      3.0.0           py312h06a4308_0
# zipp                      3.21.0             pyhd8ed1ab_1    conda-forge
# zlib                      1.3.1                hb9d3cd8_2    conda-forge
# zstd                      1.5.6                ha6fb4c9_0    conda-forge
#
# No errors reported.
#
#
# No warnings reported.
#
# --------------------------------------------------------------------------------
# If requested, please copy and paste the information between
# the dashed (----) lines, or from a given specific section as
# appropriate.
#
# =============================================================
# IMPORTANT: Please ensure that you are happy with sharing the
# contents of the information present, any information that you
# wish to keep private you should remove before sharing.
# =============================================================

# %%
import math
import numba.cuda as cuda

# %%
@cuda.jit
def vecAdd_cuda(z, x, y):
    # i = cuda.blockIdx.x*cuda.blockDim.x + threadIdx.x
    i = cuda.grid(1)
    N = x.shape[0]
    if i >= N:
        return

    z[i] = x[i] + math.exp(y[i])

# %%
import numpy as np

rng = np.random.default_rng()

N = 10240000
x = rng.random(N)
y = rng.random(N)

# %%
# %%time
z_ref = x + np.exp(y)
# Out:
# CPU times: user 13.9 ms, sys: 12.5 ms, total: 26.3 ms
# Wall time: 27.7 ms

# %%
d_x = cuda.to_device(x)
d_y = cuda.to_device(y)
d_z = cuda.device_array_like(x)

# %%
block_size = 128
num_blocks = (N-1)//block_size+1

# %%
# %%time
vecAdd_cuda[num_blocks, block_size](d_z, d_x, d_y)
# Out:
# CPU times: user 189 μs, sys: 0 ns, total: 189 μs
# Wall time: 192 μs

# %%
res = d_z.copy_to_host()

# %%
assert np.allclose(z_ref, res)
